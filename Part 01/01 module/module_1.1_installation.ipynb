# %% [markdown]
# <center>
# <img src="https://cdn.megabonus.com/images/shop_logo/skillbox.png"/>
#
# # Курс аналитик данных на Python
#
# ## Модуль 1.1.  Настройка окружения и установка Jupyter Notebook

# %% [markdown]
# ---

# %% [markdown]
# <img src="https://1.bp.blogspot.com/-16utHnlB3Ao/V4tpG8NBX0I/AAAAAAAAA7M/vDQ1p40JpE8M34eCr-UdriSV04Dn8au7QCLcB/s1600/jupyter-logo.png" style="height:90px;" />
#
#
# <img src="https://upload.wikimedia.org/wikipedia/en/c/cd/Anaconda_Logo.png" style="height:190px;" />

# %% [markdown]
# ---

# %% [markdown]
# Итак, на этом коротком вводном уроке мы с вами сделаем:
#
# - **Установим** сам **Python**
# - **Установим** интерактивную среду разработки на Python - **Jupyter Notebook** и разберемся как в ней работать
# - Посмотрим какие **полезные фишки** есть у этого инструмента
# - Сохраним **список полезных ссылок** для изучения и тренировки

# %% [markdown]
# ## 1. Установка Jupyter notebook
#
# 1) Самый простой способ установить все разом это [установить дистрибутив Anaconda](https://www.anaconda.com/download/) для своей операционной системы. В этом дистрибутиве уже есть  `jupyter notebook`, небольшая ide и предустановлен широкий спект пакетов.
#
# _Наши шаги:_ <br>
# * Скачать дистрибутив для своей операционной системы
# * Открыть командную строку/терминал
# * Запустить Jupyter notebook, написав в консоли `jupyter notebook`
#
# Через несколько секунд должна открыться страница в браузере со списком файлов директории, в котороый была запущена команда (можно не ждать и самим перейти по http://localhost:8888/ - обычно там располагается локальный "сервер" Jupyter Notebook`
#
# 2) Альтернативный версии установки (например через `pip`) лежит [тут](http://jupyter.readthedocs.org/en/latest/install.html)

# %% [markdown]
# Чтобы убедиться, что у нас все установилось можно проверить версию можно напечатав в командной строке/консоле/терминале `python --version` и нажав `Enter`

# %% [markdown]
# ## 2. Онлайн Jupyter Notebook
#
# Можно ничего не устанавливать и работать с сайтом https://jupyter.org/try
#
# На сайте можно создать новый файл `(New -> Python 2/3)` или загрузить файл с компьютера с помощью `Upload`.
#
# **WARNING**!
# <b>Сайт не сохраняет ваши файлы</b> и удаляет их после закрытия страницы.
# Чтобы загрузить файл себе откройте его нажмите `File -> Download as -> ipynb`.
#
# Можно так же пользоваться сайтом https://cloud.sagemath.com/.

# %% [markdown]
# ## 3. Работа с Python в Jupyter Notebook
#
# Чтобы создать новый файл, кликните New -> Python.
#
# Ноутбук состоит из ячеек (cells), которые бывают текстовыми (Markdown) и кодовыми (Code).
# Выбрать тип ячейки можно на панели управления.
#
# Работа с ячейками:
# <ul>
#     <li> Выбор ячейки — нажмите на нее мышкой.</li>
#     <li> Редактирование — нажмите на нее два раза.</li>
#     <li> Запуск ячейки — `SHIFT+ENTER` или нажмите на кнопку <button class='fa fa-play icon-play btn btn-xs btn-default'></button> на панеле.</li>
#     <li> Добавление новой ячейки — нажмите на кнопку <button class='fa fa-plus icon-plus btn btn-xs btn-default'></button> на панеле.</li>
#     <li> Удаление ячейки — нажмите на кнопку <button class='fa fa-cut icon-cut btn btn-xs btn-default'></button> на панеле.</li>
#     <li> Перемещение ячейки — нажмите на вертикальные стрелки.</li>
#    <li> И много другое в `Help => Keyboarn shortcuts`...</li>
# </ul>

# %% [markdown]
# Так же в ячейках можно писать, используя научную нотацию например формулы $\LaTeX$ и `html`-команды:
#
# **Пример:** $$f(x) = \frac{1}{x}$$
#
# $\LaTeX$ cheat sheet -  https://wch.github.io/latexsheet/

# %% [markdown]
# ## 4. Импорт библиотек

# %% [markdown]
# Мы будем работать **Jupyter Notebook** или в [**IDE**](https://ru.wikipedia.org/wiki/%D0%98%D0%BD%D1%82%D0%B5%D0%B3%D1%80%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%BD%D0%B0%D1%8F_%D1%81%D1%80%D0%B5%D0%B4%D0%B0_%D1%80%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B8), или по другому, в среде разработки, специальном текстовом редакторе, где удобнее писать код.
# Первое что нужно делать это импортировать библиотеки, из которых мы будем брать методы для создания и взаимодействия с объектами, чтобы непосредственно запрограммировать логику.<br>
# В нашем курсе нам понадобится довольно много библиотек, но ключевые мы уже знаем или слышали о них. Это [**numpy**](https://docs.scipy.org/doc/numpy-1.15.1/reference/) и [**pandas**](http://pandas.pydata.org/pandas-docs/stable/), а импортировать их очень легко.

# %%
import numpy as np # используется для математических вычислений разного рода
import pandas as pd # используется для работы с табличными данными

# %% [markdown]
# Мы используем сокращение **_as np_** и **_as pd_**, для удобства обращения к библиотекам, когда мы будем применять методы к объектам и как дань общепринятой культуры. <br>

# %% [markdown]
# Также в начале курса нам понадобятся еще пару библиотек для визуализации данных, а по ходу курса будут добавляться специфические библиотеки.

# %%
import matplotlib.pyplot as plt # используется для визуализации базовых графиков
import seaborn as sns # надстройка над библиотекой matplotlib, чтобы рисовать более сложные графики

# %% [markdown]
# Импортировать библиотеки как мы делали выше получится, если они у нас установлены, но если мы не установливали пакет, то выскочит ошибка.

# %%
import somepackage
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import somepackage
#
# ModuleNotFoundError: No module named 'somepackage'

# %% [markdown]
# Мы уже говорили о `pip` выше, когда говорили про установку `jupyter notebook`. С его же помощью мы можем устанавливать и другие пакеты.
#
# <br>
# Но в нашем случае мы установили [дистрибутив Anaconda](https://www.anaconda.com/download/) в котором, во-первых, уже предустановлено многопо пулярных библиотек, а во-вторых, можно легко найти и установить требуемыый пакет `Environment => Search Packages`
#
# <br>
# Тем не менее, установка через `pip` в командной строке это рекоммендуемый способ для установки.

# %% [markdown]
# ## 5. Список полезных материалов для изучения и тренировки

# %% [markdown]
# * Сайт языка Python - https://www.python.org/

# %% [markdown]
# * Интерактивный курс Python с нуля - http://pythontutor.ru/

# %% [markdown]
# * Самоучитель Python - https://pythonworld.ru/samouchitel-python

# %% [markdown]
# * Статья про коварности Python - https://habrahabr.ru/company/mailru/blog/337364/

# %% [markdown]
# * Очень полезные трюки в Jupyter Notebook: https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/
